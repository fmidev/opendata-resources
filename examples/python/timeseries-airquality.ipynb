# %% [markdown]
# # Fetching air quality data from the FMI open data timeseries API
#
# [API documentation](https://github.com/fmidev/smartmet-plugin-timeseries/blob/master/docs/Using-the-Timeseries-API.md),
# [API examples](https://github.com/fmidev/smartmet-plugin-timeseries/blob/master/docs/Examples.md),
# [JSON API example call.](https://opendata.fmi.fi/timeseries?format=json&groupareas=0&producer=airquality_urban&area=Helsinki&param=time,fmisid,PM10_PT1H_avg,PM25_PT1H_avg,O3_PT1H_avg,CO_PT1H_avg,SO2_PT1H_avg,NO2_PT1H_avg,TRSC_PT1H_avg)

# %%
import requests
import datetime
import pandas as pd
import numpy as np

# %%
end_time = datetime.datetime.utcnow()
start_time = end_time - datetime.timedelta(days=1)

aq_fields = {
    'fmisid': np.int32,
    'time': np.datetime64,
    'AQINDEX_PT1H_avg': np.float64,
    'PM10_PT1H_avg': np.float64,
    'PM25_PT1H_avg': np.float64,
    'O3_PT1H_avg': np.float64,
    'CO_PT1H_avg': np.float64,
    'SO2_PT1H_avg': np.float64,
    'NO2_PT1H_avg': np.float64,
    'TRSC_PT1H_avg': np.float64,
}

url = 'https://opendata.fmi.fi/timeseries'

params = {
    'format': 'json',
    'precision': 'double',
    'groupareas': '0',
    'producer': 'airquality_urban',
    'area': 'Uusimaa',
    'param': ','.join(aq_fields.keys()),
    'starttime': start_time.isoformat(timespec="seconds"),
    'endtime': end_time.isoformat(timespec="seconds"),
    'tz': 'UTC',
}

data = requests.get(url, params=params).json()

# %%
df = pd.DataFrame(data).astype(aq_fields)
# df = df.set_index(['fmisid', 'time'])
df[0:10]
# Out:
#    fmisid                time  AQINDEX_PT1H_avg  PM10_PT1H_avg  PM25_PT1H_avg  \
# 0  100662 2022-08-25 09:00:00               2.0            8.4            4.1
# 1  100662 2022-08-25 10:00:00               2.0           10.1            5.9
# 2  100662 2022-08-25 11:00:00               1.0           10.2            5.8
# 3  100662 2022-08-25 12:00:00               1.0           10.6            5.3
# 4  100662 2022-08-25 13:00:00               1.0           13.3            4.6
# 5  100662 2022-08-25 14:00:00               1.0           12.8            4.4
# 6  100662 2022-08-25 15:00:00               1.0            6.8            4.2
# 7  100662 2022-08-25 16:00:00               1.0            5.6            2.8
# 8  100662 2022-08-25 17:00:00               1.0            6.8            3.9
# 9  100662 2022-08-25 18:00:00               1.0            6.6            3.8
#
#    O3_PT1H_avg  CO_PT1H_avg  SO2_PT1H_avg  NO2_PT1H_avg  TRSC_PT1H_avg
# 0         61.9          NaN           1.2           5.3            NaN
# 1         60.2          NaN           1.1           7.4            NaN
# 2         54.2          NaN           0.9           6.4            NaN
# 3         44.9          NaN           1.1           8.0            NaN
# 4         41.2          NaN           1.2           8.5            NaN
# 5         42.0          NaN           1.7           9.3            NaN
# 6         46.7          NaN           1.4           8.4            NaN
# 7         49.2          NaN           1.2           7.4            NaN
# 8         44.1          NaN           1.2          11.5            NaN
# 9         50.2          NaN           1.1           8.2            NaN

# %%
df.to_parquet('data/airquality.parquet', compression='zstd')

# %% [markdown]
# # DuckDB

# %%
import duckdb
con = duckdb.connect(database=':memory:')

# %%
con.execute('CREATE OR REPLACE TABLE airquality_urban AS SELECT * FROM df')

# %%
df2 = con.execute('SELECT * FROM airquality_urban').fetchdf()
df2.sample(10)
# Out:
#      fmisid                time  AQINDEX_PT1H_avg  PM10_PT1H_avg  \
# 306  104083 2022-08-26 07:00:00               1.0           12.8
# 253  104048 2022-08-26 02:00:00               1.0            5.1
# 121  100763 2022-08-25 11:00:00               1.0            7.6
# 52   100723 2022-08-25 13:00:00               1.0            4.4
# 302  104083 2022-08-26 03:00:00               1.0            7.9
# 239  104048 2022-08-25 12:00:00               1.0            7.2
# 334  107399 2022-08-25 11:00:00               1.0            8.6
# 179  103139 2022-08-25 21:00:00               1.0            NaN
# 200  103140 2022-08-25 19:00:00               1.0            NaN
# 206  103140 2022-08-26 01:00:00               1.0            NaN
#
#      PM25_PT1H_avg  O3_PT1H_avg  CO_PT1H_avg  SO2_PT1H_avg  NO2_PT1H_avg  \
# 306            5.8          NaN          NaN           NaN          17.1
# 253            3.3          NaN          NaN           NaN           1.9
# 121            4.0          NaN          NaN           NaN           8.1
# 52             2.4         42.3          NaN           0.5           1.2
# 302            5.7          NaN          NaN           NaN           5.7
# 239            3.1          NaN          NaN           NaN           9.2
# 334            4.3          NaN          NaN           NaN           5.4
# 179            NaN         38.0          NaN          -0.2           1.2
# 200            NaN          NaN          NaN           0.2           NaN
# 206            NaN          NaN          NaN           0.2           NaN
#
#      TRSC_PT1H_avg
# 306            NaN
# 253            NaN
# 121            NaN
# 52             NaN
# 302            NaN
# 239            NaN
# 334            NaN
# 179            NaN
# 200           -0.1
# 206            0.2
